# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Importing inpatient data obtained from cms.gov after cleaning in SQL
inpatient_file = pd.read_excel('C:\inpatient.xlsx')

# %%
# Importing outpatient data obtained from cms.gov after cleaning in SQL
outpatient_file = pd.read_excel('C:\outpatient.xlsx')

# %%
# Importing "sample part d" data set for finding claims and detecting fraud
import datetime
import urllib
 
from bokeh.plotting import *
from bokeh.models import HoverTool
from collections import OrderedDict

query = ("https://data.cms.gov/resource/4uvc-gbfz.json")
raw_data = pd.read_json(query)

# %%
#converting into dataframes
inpatient_data = pd.DataFrame

# %%
inpatient = inpatient_file
inpatient
# Out:
#                                            DRG Definition  Provider Id  \
# 0       001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...        10033
# 1       001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...        30103
# 2       001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...        50108
# 3       001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...        50262
# 4       001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...        50441
# 5       001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...        50454
# 6       001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...        50625
# 7       001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...        70022
# 8       001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...        70025
# 9       001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...        90011
# 10      001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...       100007
# 11      001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...       100113
# ...

# %%
outpatient_data = pd.DataFrame
outpatient=outpatient_file

# %%
# Grouping data by city, state and finding total payments by summing them
df1= outpatient.groupby(['Provider State','Provider City','Provider Id','APC']).sum()

# %%
df1
# Out:
#                                                                                              Provider Zip Code  \
# Provider State Provider City Provider Id APC
# AK             ANCHORAGE     20001       0013 - Level II Debridement & Destruction                       99508
#                                          0015 - Level III Debridement & Destruction                      99508
#                                          0078 - Level III Pulmonary Treatment                            99508
#                                          0204 - Level I Nerve Injections                                 99508
#                                          0206 - Level II Nerve Injections                                99508
#                                          0265 - Level I Diagnostic and Screening Ultrasound              99508
#                                          0267 - Level III Diagnostic and Screening Ultra...              99508
# ...

# %%
# Exporting data as an excel file
out_xlsx = 'df1.xlsx'
df1.to_excel(out_xlsx)

# %%
df4 = inpatient.groupby(['DRG Definition']).sum()
result= df4.sort_values(['Total Discharges'],ascending = 0)

# %%
df4 = inpatient.groupby(['DRG Definition']).sum()

# %%
# Obtaining data for the DRG code 470 across USA
combined_data1 = inpatient[inpatient['DRG Definition']=='470 - MAJOR JOINT REPLACEMENT OR REATTACHMENT OF LOWER EXTREMITY W/O MCC']

# %%
out_xlsx = 'df4.xlsx'
df4.to_excel(out_xlsx)

# %%
combined_data1
# Out:
#                                            DRG Definition  Provider Id  \
# 132396  470 - MAJOR JOINT REPLACEMENT OR REATTACHMENT ...        10001
# 132397  470 - MAJOR JOINT REPLACEMENT OR REATTACHMENT ...        10005
# 132398  470 - MAJOR JOINT REPLACEMENT OR REATTACHMENT ...        10006
# 132399  470 - MAJOR JOINT REPLACEMENT OR REATTACHMENT ...        10007
# 132400  470 - MAJOR JOINT REPLACEMENT OR REATTACHMENT ...        10011
# 132401  470 - MAJOR JOINT REPLACEMENT OR REATTACHMENT ...        10016
# 132402  470 - MAJOR JOINT REPLACEMENT OR REATTACHMENT ...        10019
# 132403  470 - MAJOR JOINT REPLACEMENT OR REATTACHMENT ...        10021
# 132404  470 - MAJOR JOINT REPLACEMENT OR REATTACHMENT ...        10023
# 132405  470 - MAJOR JOINT REPLACEMENT OR REATTACHMENT ...        10024
# 132406  470 - MAJOR JOINT REPLACEMENT OR REATTACHMENT ...        10029
# 132407  470 - MAJOR JOINT REPLACEMENT OR REATTACHMENT ...        10033
# ...

# %%
# Obtaining data state wise for DRG code 470
df4 = combined_data1.groupby(['Provider State','DRG Definition']).sum()
result= df4.sort_values(['Total Discharges'],ascending = 0)

# %%
result
# Out:
#                                                                    Provider Id  \
# Provider State DRG Definition
# CA             470 - MAJOR JOINT REPLACEMENT OR REATTACHMENT O...     11880267
# FL             470 - MAJOR JOINT REPLACEMENT OR REATTACHMENT O...     15523788
# TX             470 - MAJOR JOINT REPLACEMENT OR REATTACHMENT O...    109485085
# NY             470 - MAJOR JOINT REPLACEMENT OR REATTACHMENT O...     39950332
# IL             470 - MAJOR JOINT REPLACEMENT OR REATTACHMENT O...     15415670
# PA             470 - MAJOR JOINT REPLACEMENT OR REATTACHMENT O...     52278683
# MI             470 - MAJOR JOINT REPLACEMENT OR REATTACHMENT O...     20020698
# NC             470 - MAJOR JOINT REPLACEMENT OR REATTACHMENT O...     26866719
# OH             470 - MAJOR JOINT REPLACEMENT OR REATTACHMENT O...     44295526
# VA             470 - MAJOR JOINT REPLACEMENT OR REATTACHMENT O...     29894129
# ...

# %%
# Finding no of discharges based on DRG codes
df4 = inpatient.groupby(['DRG Definition']).count()
result= df4.sort_values(['Total Discharges'],ascending = 0)

# %%
result
# Out:
#                                                     Provider Id  \
# DRG Definition
# 194 - SIMPLE PNEUMONIA & PLEURISY W CC                     2837
# 871 - SEPTICEMIA OR SEVERE SEPSIS W/O MV 96+ HO...         2837
# 292 - HEART FAILURE & SHOCK W CC                           2774
# 392 - ESOPHAGITIS, GASTROENT & MISC DIGEST DISO...         2743
# 690 - KIDNEY & URINARY TRACT INFECTIONS W/O MCC            2731
# 470 - MAJOR JOINT REPLACEMENT OR REATTACHMENT O...         2702
# 603 - CELLULITIS W/O MCC                                   2653
# 291 - HEART FAILURE & SHOCK W MCC                          2646
# 872 - SEPTICEMIA OR SEVERE SEPSIS W/O MV 96+ HO...         2588
# 190 - CHRONIC OBSTRUCTIVE PULMONARY DISEASE W MCC          2585
# 641 - MISC DISORDERS OF NUTRITION,METABOLISM,FL...         2559
# 193 - SIMPLE PNEUMONIA & PLEURISY W MCC                    2530
# 191 - CHRONIC OBSTRUCTIVE PULMONARY DISEASE W CC           2457
# ...

# %%
# Obtaining results for states
df1= inpatient.groupby(['DRG Definition','Provider State']).sum()
result2 = df1.sort_values(['Total Discharges'],ascending=0)

# %%
result2
# Out:
#                                                                    Provider Id  \
# DRG Definition                                     Provider State
# 871 - SEPTICEMIA OR SEVERE SEPSIS W/O MV 96+ HO... CA                 13644931
# 470 - MAJOR JOINT REPLACEMENT OR REATTACHMENT O... CA                 11880267
#                                                    FL                 15523788
# 871 - SEPTICEMIA OR SEVERE SEPSIS W/O MV 96+ HO... TX                101888112
# 470 - MAJOR JOINT REPLACEMENT OR REATTACHMENT O... TX                109485085
# 871 - SEPTICEMIA OR SEVERE SEPSIS W/O MV 96+ HO... NY                 48205197
#                                                    FL                 16325089
# 470 - MAJOR JOINT REPLACEMENT OR REATTACHMENT O... NY                 39950332
#                                                    IL                 15415670
# 392 - ESOPHAGITIS, GASTROENT & MISC DIGEST DISO... FL                 16525508
# ...

# %%
# Finding discharges and drgs city wise
df1= inpatient.groupby(['DRG Definition','Provider City']).sum()
result3 = df1.sort_values(['Total Discharges'],ascending=0)

# %%
result3
# Out:
#                                                                     Provider Id  \
# DRG Definition                                     Provider City
# 470 - MAJOR JOINT REPLACEMENT OR REATTACHMENT O... NEW YORK             2641147
# 885 - PSYCHOSES                                    CHICAGO              1121315
# 470 - MAJOR JOINT REPLACEMENT OR REATTACHMENT O... BOSTON               1760638
#                                                    SPRINGFIELD          3421284
# 871 - SEPTICEMIA OR SEVERE SEPSIS W/O MV 96+ HO... SPRINGFIELD          2800722
# 945 - REHABILITATION W CC/MCC                      BALTIMORE            1470252
# 470 - MAJOR JOINT REPLACEMENT OR REATTACHMENT O... BALTIMORE            2730340
# 871 - SEPTICEMIA OR SEVERE SEPSIS W/O MV 96+ HO... HOUSTON              8376253
# 885 - PSYCHOSES                                    BALTIMORE            2100250
# 470 - MAJOR JOINT REPLACEMENT OR REATTACHMENT O... HOUSTON              7196196
# ...

# %%
import numpy as np
import pandas as pd
import datetime
import urllib
 
from bokeh.plotting import *
from bokeh.models import HoverTool
from collections import OrderedDict

query = ("https://data.cms.gov/resource/4uvc-gbfz.json")
raw_data = pd.read_json(query) # sample part d data set

# %%
Partd=raw_data

# %%
Partd
# Out:
#      bene_count  bene_count_ge65 bene_count_ge65_redact_flag description_flag  \
# 0           NaN              NaN                           *                S
# 1          16.0              NaN                           #                S
# 2          17.0              NaN                           #                S
# 3          11.0              NaN                           *                S
# 4          28.0              NaN                           #                S
# 5          14.0              NaN                           *                S
# 6          26.0             15.0                         NaN                S
# 7          25.0              NaN                           *                S
# 8           NaN              NaN                           *                S
# 9          11.0              NaN                           *                S
# 10         11.0              NaN                           #                S
# ...

# %%
# Finding claims state wise
claimcount= Partd.groupby(['nppes_provider_state']).sum()
result4 = claimcount.sort_values(['total_claim_count'],ascending=0)

# %%
result4
# Out:
#                       bene_count  bene_count_ge65           npi  \
# nppes_provider_state
# FL                        5570.0           1575.0  389164751704
# CA                        2212.0            834.0   98294153122
# PA                         923.0             48.0  131393068077
# WA                        1104.0            197.0   86258204594
# MA                         393.0             77.0   89267205768
# KY                         269.0             17.0   69207062238
# IA                         104.0             15.0   20060054840
# MI                         341.0              0.0   38114071592
# NY                         199.0             54.0   18054036126
# OH                         109.0              0.0   16048003396
# NJ                         107.0              NaN   10030020720
# TX                          53.0              0.0    8024021016
# MD                         112.0             15.0    7021000882
# ...
